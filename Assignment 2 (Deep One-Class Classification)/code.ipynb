# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import numpy as np

# %%
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)


def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    mean = torch.mean(x)  # mean over all features (pixels) per sample
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %%
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from PIL import Image
class MNIST_loader(data.Dataset):
    """This class is needed to processing batches for the dataloader."""
    def __init__(self, data, target, transform):
        self.data = data
        self.target = target
        self.transform = transform

    def __getitem__(self, index):
        """return transformed items."""
        x = self.data[index]
        y = self.target[index]
        if self.transform:
            x = Image.fromarray(x.numpy(), mode='L')
            x = self.transform(x)
        return x, y

    def __len__(self):
        """number of samples."""
        return len(self.data)


def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    """get dataloders"""
    # min, max values for each class after applying GCN (as the original implementation)
    min_max = [(-0.8826567065619495, 9.001545489292527),
                (-0.6661464580883915, 20.108062262467364),
                (-0.7820454743183202, 11.665100841080346),
                (-0.7645772083211267, 12.895051191467457),
                (-0.7253923114302238, 12.683235701611533),
                (-0.7698501867861425, 13.103278415430502),
                (-0.778418217980696, 10.457837397569108),
                (-0.7129780970522351, 12.057777597673047),
                (-0.8280402650205075, 10.581538445782988),
                (-0.7369959242164307, 10.697039838804978)]

    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Lambda(lambda x: global_contrast_normalization(x)),
                                    transforms.Normalize([min_max[args.normal_class][0]],
                                                         [min_max[args.normal_class][1] \
                                                         -min_max[args.normal_class][0]])])
    train = datasets.MNIST(root=data_dir, train=True, download=True)
    test = datasets.MNIST(root=data_dir, train=False, download=True)

    x_train = train.data
    y_train = train.targets

    x_train = x_train[np.where(y_train==args.normal_class)]
    y_train = y_train[np.where(y_train==args.normal_class)]
                                    
    data_train = MNIST_loader(x_train, y_train, transform)
    dataloader_train = DataLoader(data_train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    x_test = test.data
    y_test = test.targets
    y_test = np.where(y_test==args.normal_class, 0, 1)
    data_test = MNIST_loader(x_test, y_test, transform)
    dataloader_test = DataLoader(data_test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

# %%
# !pip install barbar
# Out:
# Requirement already satisfied: barbar in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
import torch.nn as nn
import torch.nn.functional as F
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)


class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat

# %%
from torch import optim
import torch.nn.functional as F

import numpy as np
from barbar import Bar



class TrainerDeepSVDD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SVDD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSVDD(ae, self.train_loader) 
    

    def save_weights_for_DeepSVDD(self, model, dataloader):
        """Initialize Deep SVDD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SVDD model"""
        net = network().to(self.device)
        
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)

                optimizer.zero_grad()
                z = net(x)
                loss = torch.mean(torch.sum((z - c) ** 2, dim=1))
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SVDD... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

# %%
from sklearn.metrics import roc_auc_score


def eval(net, c, dataloader, device):
    """Testing the Deep SVDD model"""

    scores = []
    labels = []
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y in dataloader:
            x = x.float().to(device)
            z = net(x)
            score = torch.sum((z - c) ** 2, dim=1)

            scores.append(score.detach().cpu())
            labels.append(y.cpu())
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    return labels, scores

# %%
class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass

# %%
import matplotlib.pyplot as plt
import pandas as pd
nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SVDD = TrainerDeepSVDD(args, data, device)
  if args.pretrain:
      deep_SVDD.pretrain()
  deep_SVDD.train()
  print("test for calss  ",i,".....")
  labels, scores = eval(deep_SVDD.net, deep_SVDD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 143.694
# 5923/5923: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 110.782
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 83.048
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 61.675
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 46.569
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 36.388
# 5923/5923: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 29.278
# 5923/5923: [==============================>.] - ETA 0.4s
# Pretraining Autoencoder... Epoch: 7, Loss: 24.287
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 20.825
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 18.273
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 16.302
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.746
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.494
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.446
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.569
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.814
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.163
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.593
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.097
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.638
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.253
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.097
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.054
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.038
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.030
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.024
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.021
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.018
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.016
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.014
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.013
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.012
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.010
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.010
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.009
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.009
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.008
# test for calss   0 .....
# Testing...
# ROC AUC score: 98.01
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 148.259
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 107.293
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 78.308
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 57.583
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 43.341
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 33.701
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 27.027
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 22.283
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.805
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.173
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.122
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 12.501
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 11.173
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 10.093
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 9.202
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 8.449
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 7.812
# 6742/6742: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 17, Loss: 7.264
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 6.786
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 6.363
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.115
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.034
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.018
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.013
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.011
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.009
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.008
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.007
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.006
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.006
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.003
# test for calss   1 .....
# Testing...
# ROC AUC score: 99.70
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 141.100
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 106.646
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 78.906
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 58.765
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 44.909
# 5958/5958: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 5, Loss: 35.345
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 28.585
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 23.806
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 20.348
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 17.771
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.816
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.290
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.067
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.071
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.246
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.553
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.960
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.443
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.984
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.589
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.188
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.079
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.046
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.031
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.024
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.020
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.017
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.015
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.013
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.012
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.010
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.009
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.009
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.008
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.007
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   2 .....
# Testing...
# ROC AUC score: 84.17
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 138.760
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 102.024
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 74.863
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 55.450
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 42.184
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 33.117
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 26.794
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 22.304
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 19.031
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.575
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.682
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.196
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.011
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.045
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.254
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 9.588
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.031
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 8.554
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.132
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 7.762
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.171
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.073
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.046
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.034
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.028
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.023
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.020
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.017
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.015
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.014
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.012
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.012
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.010
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.009
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.009
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.008
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.008
# test for calss   3 .....
# Testing...
# ROC AUC score: 91.14
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 156.550
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 120.999
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 90.173
# 5842/5842: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 3, Loss: 66.866
# 5842/5842: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 4, Loss: 50.777
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 39.757
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 32.109
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 26.701
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 22.737
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 19.803
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.539
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 15.780
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.342
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.160
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.205
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.379
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.652
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.043
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.515
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.049
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.109
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.048
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.029
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.021
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.017
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.014
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.012
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.009
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.008
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.007
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.006
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.006
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.006
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.005
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.005
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.005
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.005
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.005
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.004
# test for calss   4 .....
# Testing...
# ROC AUC score: 95.53
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 166.865
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 135.494
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 105.985
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 79.605
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 60.376
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 46.904
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 37.595
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 31.004
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 26.229
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 22.679
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 19.975
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 17.848
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 16.160
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 14.776
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 13.637
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 12.706
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.906
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 11.231
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.657
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 10.152
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.113
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.048
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.030
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.023
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.020
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.016
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.015
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.014
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.012
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.011
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.010
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.010
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.009
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.008
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.009
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   5 .....
# Testing...
# ROC AUC score: 82.79
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 159.353
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 125.419
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 95.716
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 71.366
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 53.990
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 41.870
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 6, Loss: 33.441
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 27.641
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 23.518
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 20.473
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 18.168
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 16.365
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.933
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.771
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.825
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 12.038
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.373
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.801
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.310
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.884
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.422
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.156
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.087
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.060
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.047
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.039
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.034
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.029
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.026
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.024
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.022
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.020
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.018
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.017
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.016
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.015
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.015
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.014
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.013
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.013
# test for calss   6 .....
# Testing...
# ROC AUC score: 94.41
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 183.905
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 150.189
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 124.344
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 97.562
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 71.840
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 51.469
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 38.667
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 30.762
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 25.565
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 21.925
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 19.247
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 17.208
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 15.608
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 14.297
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 13.208
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 12.295
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.526
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.849
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.275
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.774
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.168
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.065
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.039
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.028
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.022
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.018
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.016
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.014
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.012
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.011
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.010
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.009
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.008
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.008
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.006
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.006
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.006
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.005
# test for calss   7 .....
# Testing...
# ROC AUC score: 95.05
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 122.456
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 89.064
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 64.373
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 47.475
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 36.537
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 29.199
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 24.114
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 20.471
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 17.826
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 15.824
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.302
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.077
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.081
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.257
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.585
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.015
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.525
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.116
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.745
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.411
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.090
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.045
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.030
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.023
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.018
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.015
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.013
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.011
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.010
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.009
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.008
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.005
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.005
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.005
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.005
# test for calss   8 .....
# Testing...
# ROC AUC score: 94.13
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 111.619
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 80.298
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 58.469
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 44.277
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 34.916
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 28.575
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 24.101
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 20.842
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.396
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.526
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.050
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.840
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.852
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.041
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.364
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.783
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.289
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.845
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.445
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.081
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.273
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.117
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.063
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.041
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.031
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.024
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.020
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.017
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.015
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.013
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.012
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.011
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.010
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for calss   9 .....
# Testing...
# ROC AUC score: 95.98

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  98.01434454047696
# ROC scores for class  1  is:  99.69627625344435
# ROC scores for class  2  is:  84.16739276255282
# ROC scores for class  3  is:  91.13904338153503
# ROC scores for class  4  is:  95.5270721286551
# ROC scores for class  5  is:  82.78654403264466
# ROC scores for class  6  is:  94.40928416173375
# ROC scores for class  7  is:  95.05034903226814
# ROC scores for class  8  is:  94.12786970426752
# ROC scores for class  9  is:  95.97929611144016

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for calss '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
